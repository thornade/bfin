# %%
import bfin

bfin.viewit("US18482P1030",start="2018-01-01").render_notebook()
# Out:
# pRSI_Bearish= 62  	 pRSI_Bullish= 46  	 pPCHC_Bearish= 0  	 pPCHC_Bullish= 21
# DFBM ANA Gain: 361.8 DB BM Gain: 175.88
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8b2181d10abe47e0934304ffe5081207" style="width:1500px; height:500px;"></div>
#                 <style>
#             .fl-table {
#                 margin: 20px;
#                 border-radius: 5px;
#                 font-size: 12px;
#                 border: none;
#                 border-collapse: collapse;
#                 max-width: 100%;
#                 white-space: nowrap;
#                 word-break: keep-all;
#             }
#
#             .fl-table th {
#                 text-align: left;
#                 font-size: 20px;
#             }
#
#             .fl-table tr {
#                 display: table-row;
#                 vertical-align: inherit;
# ...
